# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([0, 6, 10, 11])
y = np.array([1.5, 5, 6,5.5])
plt.plot(x, y)
plt.scatter(x, y)
z = np.array([2, 8, 13, 15])
j = np.array([2, 7, 9,10.5])
plt.plot(z, j)
plt.scatter(z, j)
plt.xlabel("AGE IN WEEKS")
plt.ylabel("WEIGHT IN KILOGRAM")

plt.show()
