# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x= np.array([0,6,10])
y=([1.5,5,6])

# %%
plt.bar(x,y,color="purple",width=1)
plt.xlabel("AGE IN WEEKS")
plt.ylabel("WEIGHT IN KILOGRAM")
plt.title("T.J'S WEIGHT")
# Out:
# Text(0.5, 1.0, "T.J'S WEIGHT")
